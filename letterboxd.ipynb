# %%
# Bibliotecas usadas nas análises e nos gráficos
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.ticker import FuncFormatter

pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 50)

# %%
# Carrega os dados do Letterboxd
df = pd.read_csv("data.csv")

# %%
df.shape
# Out:
# (10002, 29)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film_title         10002 non-null  str
#  1   Release_year       0 non-null      float64
#  2   Director           9992 non-null   str
#  3   Cast               9945 non-null   str
#  4   Average_rating     9421 non-null   float64
#  5   Owner_rating       967 non-null    float64
#  6   Genres             9978 non-null   str
#  7   Runtime            9992 non-null   float64
#  8   Countries          9884 non-null   str
#  9   Original_language  9999 non-null   str
#  10  Spoken_languages   9999 non-null   str
#  11  Description        10000 non-null  str
#  12  Studios            9695 non-null   str
#  13  Watches            10002 non-null  int64
#  14  List_appearances   10002 non-null  int64
#  15  Likes              10002 non-null  int64
# ...

# %%
# Remove colunas que não serão usadas nas análises
df.drop(
    columns=[
        "Cast", "Owner_rating", "Countries", "Spoken_languages", "½", "★½",
        "★★", "★★½", "★★★½", "★★★★", "★★★★½", "Film_URL",
        "Release_year", "List_appearances"
    ],
    inplace=True
)

# %%
# Renomeia as colunas de avaliação para facilitar a leitura
df.rename(
    columns={"★": "Lowest", "★★★": "Medium", "★★★★★": "Highest"},
    inplace=True
)

# %%
df.shape
# Out:
# (10002, 15)

# %%
df.isna().sum()
# Out:
# Film_title             0
# Director              10
# Average_rating       581
# Genres                24
# Runtime               10
# Original_language      3
# Description            2
# Studios              307
# Watches                0
# Likes                  0
# Fans                   0
# Lowest                 0
# Medium                 0
# Highest                0
# Total_ratings          0
# dtype: int64

# %%
# Trata valores ausentes
mean_values = {
    "Average_rating": df["Average_rating"].mean(),
    "Runtime": df["Runtime"].mean()
}
df.fillna({
    "Studios": "Unknown",
    "Average_rating": mean_values["Average_rating"],
    "Runtime": mean_values["Runtime"],
    "Genres": "Unknown",
    "Original_language": "Unknown",
    "Director": "Unknown"
}, inplace=True)
df.dropna(subset=["Description"], inplace=True)

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
# Define os dados, cores e títulos de cada gráfico
chart_configs = [
    ("Fans", "#ff8000", "Favoritos"),
    ("Watches", "#00e054", "Mais assistidos"),
    ("Likes", "#40bcf4", "Mais curtidos")
]

fig, axes = plt.subplots(1, 3, figsize=(24, 12))
fig.suptitle("Top 50 filmes no Letterboxd", fontsize=12, fontweight="bold")


def draw_gradient_bars(ax, data, value_col, base_color, title):
    """Cria um gráfico de barras horizontais com degradê"""
    data = data.groupby("Film_title")[value_col].sum().nlargest(50).reset_index()
    count = len(data)
    color_map = LinearSegmentedColormap.from_list("grad", [base_color, "#ffffff"])
    colors = [color_map(i / (count - 1) if count > 1 else 0) for i in range(count)]
    positions = np.arange(count)

    ax.barh(positions, data[value_col], color=colors)
    ax.set_yticks(positions)
    ax.set_yticklabels(data["Film_title"])
    ax.invert_yaxis()
    ax.set_title(title, fontsize=10, fontweight="bold")
    ax.tick_params(axis="both", labelsize=8)
    ax.xaxis.set_major_formatter(
        FuncFormatter(lambda value, _: f"{value:,.0f}".replace(",", "."))
    )

    # Mostra o valor ao lado de cada barra
    offset = data[value_col].max() * 0.01 if count else 0
    for position, value in enumerate(data[value_col]):
        label = f"{value:,.0f}".replace(",", ".")
        ax.text(value + offset, position, label, va="center", fontsize=8)


# Gera os três gráficos
for axis, (value_col, color, title) in zip(axes, chart_configs):
    draw_gradient_bars(axis, df, value_col, color, title)
    for spine in axis.spines.values():
        spine.set_visible(False)

plt.tight_layout()
plt.show()
