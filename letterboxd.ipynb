# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.colors as mcolors
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import LinearSegmentedColormap
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 50)

# %%
df = pd.read_csv("data.csv")

# %%
df.shape
# Out:
# (10002, 29)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film_title         10002 non-null  str
#  1   Release_year       0 non-null      float64
#  2   Director           9992 non-null   str
#  3   Cast               9945 non-null   str
#  4   Average_rating     9421 non-null   float64
#  5   Owner_rating       967 non-null    float64
#  6   Genres             9978 non-null   str
#  7   Runtime            9992 non-null   float64
#  8   Countries          9884 non-null   str
#  9   Original_language  9999 non-null   str
#  10  Spoken_languages   9999 non-null   str
#  11  Description        10000 non-null  str
#  12  Studios            9695 non-null   str
#  13  Watches            10002 non-null  int64
#  14  List_appearances   10002 non-null  int64
#  15  Likes              10002 non-null  int64
# ...

# %%
df.drop(columns=["Cast","Owner_rating","Countries","Spoken_languages","½","★½","★★","★★½","★★★½","★★★★","★★★★½","Film_URL","Release_year","List_appearances"],inplace=True)

# %%
df=df.rename(columns={"★":"Lowest","★★★":"Medium","★★★★★":"Highest"})

# %%
df.shape
# Out:
# (10002, 15)

# %%
df.isna().sum()
# Out:
# Film_title             0
# Director              10
# Average_rating       581
# Genres                24
# Runtime               10
# Original_language      3
# Description            2
# Studios              307
# Watches                0
# Likes                  0
# Fans                   0
# Lowest                 0
# Medium                 0
# Highest                0
# Total_ratings          0
# dtype: int64

# %%
x=df["Studios"].value_counts().reset_index()
df["Studios"]=df["Studios"].fillna("Unknown")
df["Average_rating"]=df["Average_rating"].fillna(df["Average_rating"].mean())
df["Runtime"]=df["Runtime"].fillna(df["Runtime"].mean())
df["Genres"]=df["Genres"].fillna("Unknown")
df.dropna(subset=["Description"],inplace=True)
df["Original_language"]=df["Original_language"].fillna("Unknown")
df["Director"]=df["Director"].fillna("Unknown")

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
classifi_ge = df.groupby("Film_title")["Fans"].sum().nlargest(50).reset_index()
classfi_mov = df.groupby("Film_title")["Watches"].sum().nlargest(50).reset_index()
classfi_li = df.groupby("Film_title")["Likes"].sum().nlargest(50).reset_index()

fig, axes = plt.subplots(1, 3, figsize=(24, 12))
fig.suptitle("Análise dos top 50 filmes no Letterboxd", fontsize=12, fontweight="bold")

def draw_gradient_bars(ax, df, value_col, base_color, title):
    n = len(df)
    cmap = LinearSegmentedColormap.from_list('grad', [base_color, '#ffffff'])
    colors = [cmap(i/(n-1) if n>1 else 0) for i in range(n)]
    y_pos = np.arange(n)
    ax.barh(y_pos, df[value_col], color=colors, edgecolor=None)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(df['Film_title'])
    ax.invert_yaxis()
    ax.set_title(title, fontsize=10, fontweight='bold')
    ax.set_xlabel('', fontsize=8)
    ax.set_ylabel('', fontsize=8)
    ax.tick_params(axis='y', labelsize=8)
    ax.tick_params(axis='x', labelsize=8)
    ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:,.0f}'.format(x).replace(',', '.')))
    x_max = df[value_col].max() if n>0 else 0
    offset = x_max * 0.01
    for i, val in enumerate(df[value_col]):
        ax.text(val + offset, i, f"{val:,.0f}".replace(',', '.'), va='center', fontsize=8)

draw_gradient_bars(axes[0], classifi_ge, 'Fans', '#ff8000', 'Favoritos')
draw_gradient_bars(axes[1], classfi_mov, 'Watches', '#00e054', 'Mais assistidos')
draw_gradient_bars(axes[2], classfi_li, 'Likes', '#40bcf4', 'Mais curtidos')

for ax in axes:
    for spine in ['top', 'right', 'left', 'bottom']:
        ax.spines[spine].set_visible(False)

plt.tight_layout()
plt.show()
